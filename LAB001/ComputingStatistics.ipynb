# %% [markdown]
# <img src="https://github.com/danielscarvalho/data/blob/master/img/FIAP-logo.png?raw=True" style="float:right;" width="200px">
#
# # DATA SCIENCE & STATISTICAL COMPUTING [》](https://www.fiap.com.br/)
#
# ## FIAP - Engenharia de Software
#
# ### Estatística, Numpy, Pandas & Bitcoins
#
# Computing Statistics - general review<br>
# Business hints

# %% [markdown]
# Referência da aula de hoje:
#
# Exemplo jornalismo de dados: CD Revenue Nearly Triples Digital Album Sales in First Half of 2024
# - https://www.headphonesty.com/2024/09/cd-revenue-triples-album-sales-first-half/
#
# Exemplo de "executive report" ou "executive summary"<br>
# Como as consultorias e auditorias (big four - PwC, Deloitte, KPMG, EY) fazem entregas para clientes...
#
# ![image.png](attachment:371b3f8e-c38a-4ef7-b4a2-00f0e4582feb.png)
#
# - PDF
# - Fonts: https://fonts.google.com/
# - Color pallets: https://colorhunt.co/
# - Design hints for business report, extra:
#   - Beginning Graphic Design: Fundamentals: https://www.youtube.com/watch?v=YqQx75OPRa0
#   - Beginning Graphic Design: Color: https://www.youtube.com/watch?v=_2LLXnUdUIc&list=RDQMc6R_Q_NfllA&index=2
#   - Beginning Graphic Design: Layout & Composition: https://www.youtube.com/watch?v=a5KYlHNKQB8
#   - Beginning Graphic Design: Typography: https://www.youtube.com/watch?v=sByzHoiYFX0
#   - Beginning Graphic Design: Branding & Identity:  https://www.youtube.com/watch?v=l-S2Y3SF3mM
#
# Python, biblioteca padrão: statistics — Funções estatísticas
# - https://docs.python.org/pt-br/3/library/statistics.html#
#
# NumPy - Statistics
# - https://numpy.org/doc/stable/reference/routines.statistics.html
#
# Think Stats: Exploratory Data Analysis in Python by Allen B. Downey
# - https://greenteapress.com/wp/think-stats-2e/
#
# Elements of Data Science by Allen B. Downey
# - https://allendowney.github.io/ElementsOfDataScience/index.html

# %% [markdown]
# Importando LIBs

# %%
import random
import statistics
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
# Dados (listas)

range_data = range(1000)
random_data = [random.random()*1000 for x in range_data]

# %% [markdown]
# Encontrar fonte WEB API para cotação do bitcoin YTD
#
# Usar uma lista simples

# %% [markdown]
# Encontrar fonte WEB API para cotação do dolar BRL USD YTD
#
# Usar uma lista simples
