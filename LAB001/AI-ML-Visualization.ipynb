# %% [markdown]
# <img src="https://github.com/danielscarvalho/data/blob/master/img/FIAP-logo.png?raw=True" style="float:right;" width="200px">
#
# # DATA SCIENCE & STATISTICAL COMPUTING [》](https://www.fiap.com.br/)
#
# ## FIAP - Engenharia de Software
#
# ### AI and ML Interactive Visualization

# %% [markdown]
# ### Tensorflow Playground
#
# ![image.png](attachment:13d54340-a315-4f16-9da4-a670354c1c6f.png)
#
# https://playground.tensorflow.org/

# %% [markdown]
# ### R2D3 - A visual introduction to machine learning
#
# ![image.png](attachment:41fbcac2-8186-422c-94cd-c4c213fadc49.png)
#
# http://www.r2d3.us/visual-intro-to-machine-learning-part-1/

# %% [markdown]
# ### MLU-EXPLAIN - Visual explanations of core machine learning concepts
#
# Machine Learning University (MLU)
#
# ![image.png](attachment:80d7bf6c-23e0-4942-bd75-01ab01783141.png)
#
#
# https://mlu-explain.github.io/

# %% [markdown]
# ### Wolfram - What is a neural net exactly?
#
# ![image.png](attachment:578415df-bf47-4081-9d90-e14fe1270e30.png)
#
# https://www.youtube.com/watch?v=IH4bdPxscyo

# %% [markdown]
# ### References
#
# How to Do Model Visualization in Machine Learning?<br>
# https://neptune.ai/blog/visualization-in-machine-learning
#
# Online Book: Introduction to Machine Learning<br>
# https://www.wolfram.com/language/introduction-machine-learning/
# <div style="width:600px">
#
# ![image.png](attachment:7398537a-d0e8-4f6b-9f97-8191539cf436.png)
#
# </div>
