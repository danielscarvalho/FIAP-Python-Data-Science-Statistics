# %% [markdown]
# <img src="https://github.com/danielscarvalho/data/blob/master/img/FIAP-logo.png?raw=True" style="float:right;" width="200px">
#
# # DATA SCIENCE & STATISTICAL COMPUTING [》](https://www.fiap.com.br/)
#
# ## Vídeos: Data Science & AI (Artificial Intelligence)

# %% [markdown]
# ### AI vs Data Science
#
# ![image.png](attachment:00503961-edd7-4a05-9952-500e4504150e.png)
#
# https://medium.com/@dhanushv/a-i-vs-data-science-1b8cd0736c02

# %% [markdown]
# ## Atividade: Semana 10 Jun 2024
#
# Assistir em pares (pairing) os seguintes documentários e reportagems sobre Ciências dos Dados, IA e Data Science.
#
# Pausar, comentar com o colega e anotar conforme andamento dos vídeos.<br>
# Realizar as anotações neste notebook.<br>
# Compartilhar com os amigos da turma suas percepções.<br>
# Encaminhar ao professor dúvidas e idéias no MS Teams.
#
# Há vídeos em Português, Inglês e Espanhol.

# %% [markdown]
# ### Artificial Intelligence | 60 Minutes Full Episodes
# - https://www.youtube.com/watch?v=aZ5EsdnpLMI&t=2224s&ab_channel=60Minutes
#
# ### DW: Inteligência Artificial: o começo de tudo
# - https://www.youtube.com/watch?v=FibKLdHJfsw&ab_channel=DWBrasil
#
# ### DW: ¿La inteligencia artificial amenaza la identidad humana? | DW Documental
# - https://www.youtube.com/watch?v=YUZoeRTRFyU&ab_channel=DWDocumental
#
# ### What is a neural net exactly?
# - https://www.youtube.com/watch?v=IH4bdPxscyo

# %% [markdown]
# ### Anotações, comentários e observações:

# %% [markdown]
# ## Extra:
#
# Recentemente os anúncios anuais da OpenAI e Google falam sobre AI, assitir e comentar:

# %% [markdown]
# ### Google IO 2024: Google Keynote (Google I/O ‘24)
# - https://www.youtube.com/watch?v=XEzRZ35urlk&ab_channel=Google
#
# ### OpenAI: Introducing GPT-4o
# - https://www.youtube.com/watch?v=DQacCB9tDaw&ab_channel=OpenAI

# %% [markdown]
# ### Anotações, comentários e observações:

# %% [markdown]
# Aqui mantenho uma lista curada de vídeos sobre ciências dos dados:
# - https://github.com/danielscarvalho/Insper-DS-Dicas/blob/master/Dica-012-V%C3%ADdeos.ipynb
